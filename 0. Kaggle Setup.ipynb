# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-db6c61a2-b6fa-4008-901b-dfc78fb03c2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db6c61a2-b6fa-4008-901b-dfc78fb03c2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kimse0ha","key":"ab8eb045a8b09416b2db3bb7b992bea4"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
from google.colab import drive  
drive.mount('/content/drive')  

import os  
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/Colab Notebooks/kaggle/"
# !chmod 600 drive/MyDrive/'Colab Notebooks'/kaggle/kaggle.json
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/'Colab Notebooks'/kaggle
# Out:
# /content/drive/MyDrive/Colab Notebooks/kaggle

# %%
ls
# Out:
# kaggle.json

# %%
# !pip install kaggle==1.5.6
# !kaggle -v
# Out:
# ...
#      |████████████████████████████████| 61kB 4.7MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.6-cp36-none-any.whl size=72859 sha256=aef2e439c91513565b2f1e196f48a9702496184486f2e2add71eb98868e0f20d
#   Stored in directory: /root/.cache/pip/wheels/57/4e/e8/bb28d035162fb8f17f8ca5d42c3230e284c6aa565b42b72674
# Successfully built kaggle
# ...
#   Found existing installation: kaggle 1.5.10
#     Uninstalling kaggle-1.5.10:
#       Successfully uninstalled kaggle-1.5.10
# ...
# Kaggle API 1.5.6

# %%
# !kaggle competitions download -c cassava-leaf-disease-classification -p /content/drive/MyDrive/'Colab Notebooks'/Cassava/data
# Out:
# ...
# 100% 5.75G/5.76G [00:58<00:00, 131MB/s]
# 100% 5.76G/5.76G [00:58<00:00, 105MB/s]

# %%
# !kaggle datasets download -d tahsin/cassava-leaf-disease-merged -p /content/drive/MyDrive/'Colab Notebooks'/Cassava/merged_data --force
# Out:
# ...
# 100% 3.08G/3.09G [01:21<00:00, 61.4MB/s]
# 100% 3.09G/3.09G [01:21<00:00, 40.5MB/s]

# %%
cd ../Cassava/merged_data
# Out:
# /content/drive/My Drive/Colab Notebooks/Cassava/merged_data

# %%
# !unzip cassava-leaf-disease-merged.zip -d /content/drive/MyDrive/'Colab Notebooks'/Cassava/merged_data
# Out:
# Archive:  cassava-leaf-disease-merged.zip
# replace /content/drive/MyDrive/Colab Notebooks/Cassava/merged_data/merged.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
cd train
# Out:
# /content/drive/My Drive/Colab Notebooks/Cassava/merged_data/train

# %%
ls -l | grep ^- | wc -l
# Out:
# 26337

# %%
# !kaggle kernels pull kimse0ha/efficientnet-train-amp-focal-loss-fmix -p /content/drive/MyDrive/'Colab Notebooks'/Cassava
# Out:
# ...
# 'latin-1' codec can't encode characters in position 199-200: ordinal not in range(256)
